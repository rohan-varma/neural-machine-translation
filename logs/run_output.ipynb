# %% [markdown]
# <a href="https://colab.research.google.com/github/rohan-varma/neural-machine-translation/blob/master/run_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/rohan-varma/neural-machine-translation.git
# Out:
# Cloning into 'neural-machine-translation'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 153 (delta 2), reused 11 (delta 2), pack-reused 141
# Receiving objects: 100% (153/153), 129.27 MiB | 41.21 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# %cd neural-machine-translation
# Out:
# /content/neural-machine-translation

# %%
! python src/seq2seq.py
# Out:
# DEBUG:matplotlib:$HOME=/root
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.0.3
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...
